# %%
import json
import gc
import pandas as pd
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer
from zeus.monitor import ZeusMonitor
from transformers import pipeline
from transformers import set_seed
from transformers import BitsAndBytesConfig

# %% [markdown]
# ### Dataset downloading
# Dataset URL: [https://huggingface.co/datasets/tinyBenchmarks/tinyAlpacaEval](https://huggingface.co/datasets/tinyBenchmarks/tinyAlpacaEval)

# %%
df = pd.read_parquet("hf://datasets/tinyBenchmarks/tinyAlpacaEval/data/test-00000-of-00001.parquet")
len(df["instruction"])
# Out:
# 100

# %% [markdown]
# ### Set seed and CUDA device

# %%
set_seed(42)

# %%
torch.cuda.get_device_name()
# Out:
# 'NVIDIA RTX A1000 6GB Laptop GPU'

# %%
torch.cuda.is_available()
# Out:
# True

# %% [markdown]
# ### Functions for LLM Benchmarking

# %%
def run_text_generation_energy_measurement(pipe, instruction_list, monitor, nb_token=256):
    """
    Measures the energy consumption and time taken for text generation using a given pipeline and a list of instructions.
    Also tracks the number of tokens in the input questions and generated responses.

    Parameters:
    pipe (object): The pipeline object that includes the tokenizer and the model for text generation.
    instruction_list (list of str): A list of instructions or prompts to be used for text generation.
    monitor (object): A Zeus object used to monitor the energy consumption and time during the text generation process.
    nb_token (int, optional): The maximum number of new tokens to generate. Default is 256.

    Returns:
    pd.DataFrame: A DataFrame containing the measured energy consumption, time, instruction dataset index,
                  question tokens, and response tokens.
    dict: A dictionary containing the generated text for each instruction.
    """
    gpu_energy = []
    time = []
    instruction_dataset_index = []
    question_tokens = []
    response_tokens = []
    dict_generated_text = {"data":[]}

    tokenizer = pipe.tokenizer

    for i in range(len(instruction_list)):
        if i % 10 == 0:
            print("Instruction index: ", i)

        message = {"role": "user", "content": instruction_list[i]}
        monitor.begin_window("generation")
        outputs = pipe(
            [message],
            max_new_tokens=nb_token
        )
        result_monitor = monitor.end_window("generation")
        gpu_energy.append(result_monitor.total_energy)
        time.append(result_monitor.time)
        instruction_dataset_index.append(i)

        
        model_inputs = tokenizer.apply_chat_template([message], add_generation_prompt=True, return_tensors="pt").to("cuda")
        input_length = model_inputs.shape[1]

        model_outputs = tokenizer.apply_chat_template([outputs[0]["generated_text"][-1]], add_generation_prompt=True, return_tensors="pt").to("cuda")
        output_length = model_outputs.shape[1]
        
        question_tokens.append(input_length)
        response_tokens.append(output_length)

        dict_generated_text["data"].append({
            "question" : outputs[0]["generated_text"][0],
            "generated_text" : outputs[0]["generated_text"][-1],
        })

    dict_results = {
        "gpu_energy": gpu_energy,
        "time": time,
        "instruction_dataset_index": instruction_dataset_index,
        "question_tokens": question_tokens,
        "response_tokens": response_tokens
    }

    return pd.DataFrame(dict_results), dict_generated_text

# %%
def run_evaluation(nb_run, pipe, instruction_list):
    """
    Runs multiple evaluations of text generation energy measurement and aggregates the results.

    Parameters:
    nb_run (int): The number of times to run the evaluation.
    pipe (object): The pipeline object that includes the tokenizer and the model for text generation.
    instruction_list (list of str): A list of instructions or prompts to be used for text generation.

    Returns:
    pd.DataFrame: A DataFrame containing the aggregated results of energy consumption, time, instruction dataset index, and run number.
    dict: A dictionary containing the generated text for each instruction from the last run.
    """
    df_all_results = pd.DataFrame({"gpu_energy": [], "time": [], "instruction_dataset_index":[], "run":[]})
    dict_generated_text = None
    for i in range(0,nb_run):
        print("Run: ", i)
        monitor = ZeusMonitor(gpu_indices=[0])
        results, dict_generated_text = run_text_generation_energy_measurement(pipe, instruction_list, monitor)
        results["run"] = i
        df_all_results = pd.concat([df_all_results, results])
    return df_all_results, dict_generated_text

# %%
def eval_models(model_id_list, nb_run, quantization_name, quantization_config, instruction_list, csv_suffixe=""):
    """
    Evaluates multiple models for text generation energy measurement and saves the results.

    Parameters:
    model_id_list (list of str): A list of model IDs to evaluate.
    nb_run (int): The number of times to run the evaluation for each model.
    quantization_name (str): The name of the quantization method used.
    quantization_config (object): The configuration object for quantization.
    instruction_list (list of str): A list of instructions or prompts to be used for text generation.
    csv_suffixe (str, optional): A suffix to add to the output CSV file names. Default is an empty string.

    Returns:
    None
    """
    for model_id in model_id_list:

        if quantization_config:
            model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=quantization_config)
            tokenizer = AutoTokenizer.from_pretrained(model_id)
        else:
            model = AutoModelForCausalLM.from_pretrained(model_id)
            tokenizer = AutoTokenizer.from_pretrained(model_id)

        pipe = pipeline(
            "text-generation",
            model=model,
            tokenizer=AutoTokenizer.from_pretrained(model_id),
            pad_token_id=tokenizer.eos_token_id
        )

        print("========= Begin Model Evaluation " + model_id + " ==========")
        df_all_results, dict_generated_text = run_evaluation(nb_run, pipe, instruction_list)
        df_all_results["quantization"] = quantization_name

        if not quantization_config:
            df_all_results["quantization_object"] = ""
            dict_generated_text["quantization_object"] = ""
        else:
            df_all_results["quantization_object"] = quantization_config.to_json_string().replace("\n", "")
            dict_generated_text["quantization_object"] = quantization_config.to_dict()

        df_all_results["model"] = model_id
        df_all_results["toech_memory_allocated"] = torch.cuda.memory_allocated(0)
        df_all_results.to_csv("results/" + model_id.split("/")[1] + csv_suffixe + ".csv", index=False)

        dict_generated_text["model"] = model_id
        dict_generated_text["quantization"] = quantization_name

        with open("results/LLM_generated_text/" + model_id.split("/")[1] + csv_suffixe + ".json", 'w', encoding='utf-8') as json_file:
            json.dump(dict_generated_text, json_file, ensure_ascii=False, indent=4)

        print("========= End Model Evaluation " + model_id + " ==========")

        del pipe
        del tokenizer
        del model
        torch.cuda.empty_cache()
        gc.collect()

# %% [markdown]
# ### Llama-3.2-1B-Instruct

# %%
model_id_list = ["Qwen/Qwen2.5-0.5B-Instruct", "ibm-granite/granite-3.1-1b-a400m-instruct","HuggingFaceTB/SmolLM2-360M-Instruct", "meta-llama/Llama-3.2-1B-Instruct"]

# %%
def eval_models_memory_footprint(model_id_list, quantization_config):
    dict_memory_footprint = {
        "model_memory_footprint": [],
        "model":[],
        "quantization":[]
    }
    for model_id in model_id_list:
        
        if quantization_config : 
            model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=quantization_config)
            tokenizer = AutoTokenizer.from_pretrained(model_id)
            print(quantization_config.is_quantizable())
        else: 
            model = AutoModelForCausalLM.from_pretrained(model_id)
            tokenizer = AutoTokenizer.from_pretrained(model_id)
        
        pipe = pipeline(
            "text-generation",
            model=model,
            tokenizer=AutoTokenizer.from_pretrained(model_id),
            pad_token_id = tokenizer.eos_token_id
        )
        
        print("========= Model Memory Footprint Evaluation "+model_id+" ==========")
        print(model.get_memory_footprint())
        print("========= End  Model Memory Footprint Evaluation "+model_id+" ==========")
        
        del pipe
        del tokenizer
        del model
        torch.cuda.empty_cache()
        gc.collect()

# %%
quantization_config = BitsAndBytesConfig(
        load_in_8bit=True,
)
eval_models_memory_footprint(model_id_list, quantization_config)
# Out:
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# True
# Device set to use cuda:0
# ========= Model Memory Footprint Evaluation Qwen/Qwen2.5-0.5B-Instruct ==========
# 630242176
# ========= End  Model Memory Footprint Evaluation Qwen/Qwen2.5-0.5B-Instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# True
# Device set to use cuda:0
# ========= Model Memory Footprint Evaluation ibm-granite/granite-3.1-1b-a400m-instruct ==========
# 2592972928
# ========= End  Model Memory Footprint Evaluation ibm-granite/granite-3.1-1b-a400m-instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# True
# Device set to use cuda:0
# ========= Model Memory Footprint Evaluation HuggingFaceTB/SmolLM2-360M-Instruct ==========
# 409073664
# ========= End  Model Memory Footprint Evaluation HuggingFaceTB/SmolLM2-360M-Instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# True
# Device set to use cuda:0
# ========= Model Memory Footprint Evaluation meta-llama/Llama-3.2-1B-Instruct ==========
# 1498552448
# ========= End  Model Memory Footprint Evaluation meta-llama/Llama-3.2-1B-Instruct ==========

# %% [markdown]
# #### Without Quantization

# %%
eval_models(model_id_list, nb_run=10, quantization_name="Without", quantization_config=None, instruction_list=df["instruction"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 eval_models(model_id_list, nb_run=10, quantization_name="Without", quantization_config=None, instruction_list=df["instruction"])
#
# NameError: name 'model_id_list' is not defined

# %% [markdown]
# ### 8-bit Quantization

# %%
quantization_config = BitsAndBytesConfig(
        load_in_8bit=True,
)
eval_models(model_id_list, nb_run=10, quantization_name="8-bit", quantization_config=quantization_config, instruction_list=df["instruction"], csv_suffixe="-q8bits")
# Out:
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation Qwen/Qwen2.5-0.5B-Instruct ==========
# Run:  0
# [2024-12-21 04:59:19,081] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 04:59:19,081] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# 285
# 253
# 80
# 285
# 275
# 90
# 285
# 285
# 192
# 285
# Instruction index:  10
# 285
# 285
# 285
# 285
# 89
# 285
# 39
# 260
# 221
# 285
# Instruction index:  20
# 285
# 285
# 79
# 37
# 213
# 41
# 285
# 148
# 59
# 285
# Instruction index:  30
# 285
# 285
# 285
# 224
# 285
# 42
# 88
# 285
# 284
# 285
# Instruction index:  40
# 285
# 86
# 41
# 285
# 102
# 65
# 248
# 284
# 41
# 38
# Instruction index:  50
# 285
# 285
# 283
# 284
# 285
# 285
# 42
# 174
# 285
# 285
# Instruction index:  60
# 75
# 285
# 264
# 212
# 285
# 285
# 285
# 285
# 285
# 285
# Instruction index:  60
# 72
# 60
# 285
# 285
# 91
# 114
# 285
# 149
# 87
# 246
# Instruction index:  70
# 285
# 41
# 285
# 147
# 140
# 221
# 212
# 284
# 72
# 43
# Instruction index:  80
# 171
# 180
# 285
# 285
# 285
# 41
# 285
# 285
# 285
# 169
# Instruction index:  90
# 214
# 285
# 285
# 285
# 42
# 285
# 130
# 97
# 285
# 79
# ========= End Model Evaluation Qwen/Qwen2.5-0.5B-Instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation ibm-granite/granite-3.1-1b-a400m-instruct ==========
# Run:  0
# [2024-12-21 06:48:07,982] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 06:48:07,983] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# 315
# 65
# 315
# 315
# 180
# 176
# 315
# 315
# 315
# 315
# Instruction index:  10
# 315
# 315
# 315
# 315
# 315
# 315
# 72
# 134
# 145
# 315
# Instruction index:  20
# 315
# 315
# 315
# 315
# 315
# 67
# 315
# 136
# 91
# 315
# Instruction index:  30
# 315
# 191
# 315
# 315
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  40
# 315
# 68
# 315
# 315
# 135
# 107
# 315
# 315
# 159
# 145
# Instruction index:  50
# 315
# 315
# 147
# 275
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  60
# 69
# 315
# 315
# 315
# 60
# 79
# 315
# 117
# 111
# 212
# Instruction index:  70
# 315
# 315
# 315
# 236
# 315
# 315
# 233
# 315
# 80
# 82
# Instruction index:  80
# 162
# 158
# 315
# 315
# 315
# 202
# 315
# 89
# 315
# 315
# Instruction index:  90
# 315
# 315
# 315
# 315
# 125
# 315
# 315
# 78
# 315
# 83
# Run:  1
# [2024-12-21 07:02:33,169] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 07:02:33,169] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# 315
# 65
# 315
# 315
# 203
# 188
# 315
# 315
# 309
# 315
# Instruction index:  10
# 315
# 315
# 315
# 315
# 315
# 315
# 72
# 126
# 145
# 315
# Instruction index:  20
# 315
# 315
# 315
# 315
# 315
# 67
# 315
# 136
# 91
# 315
# Instruction index:  30
# 315
# 158
# 315
# 315
# 315
# 315
# 315
# 315
# 315
# 314
# Instruction index:  40
# 315
# 68
# 315
# 314
# 112
# 102
# 312
# 315
# 188
# 156
# Instruction index:  50
# 315
# 315
# 146
# 275
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  60
# 69
# 315
# 315
# 315
# 60
# 79
# 315
# 103
# 67
# 224
# Instruction index:  70
# 315
# 315
# 315
# 168
# 315
# 315
# 267
# 315
# 80
# 153
# Instruction index:  80
# 191
# 153
# 315
# 315
# 315
# 202
# 315
# 89
# 315
# 161
# Instruction index:  90
# 315
# 315
# 315
# 315
# 114
# 315
# 315
# 78
# 315
# 85
# Run:  2
# [2024-12-21 07:16:48,230] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 07:16:48,230] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# 315
# 65
# 315
# 315
# 216
# 176
# 315
# 315
# 309
# 315
# Instruction index:  10
# 315
# 315
# 314
# 315
# 228
# 315
# 72
# 126
# 145
# 315
# Instruction index:  20
# 315
# 315
# 315
# 315
# 315
# 67
# 315
# 168
# 91
# 315
# Instruction index:  30
# 315
# 164
# 315
# 315
# 315
# 277
# 315
# 315
# 315
# 315
# Instruction index:  40
# 315
# 68
# 315
# 315
# 118
# 105
# 315
# 315
# 147
# 120
# Instruction index:  50
# 315
# 315
# 147
# 282
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  60
# 69
# 315
# 315
# 315
# 60
# 79
# 315
# 103
# 67
# 212
# Instruction index:  70
# 315
# 315
# 315
# 216
# 315
# 315
# 276
# 315
# 80
# 82
# Instruction index:  80
# 200
# 153
# 315
# 314
# 315
# 226
# 315
# 89
# 315
# 181
# Instruction index:  90
# 315
# 315
# 315
# 315
# 138
# 315
# 315
# 78
# 315
# 83
# Run:  3
# [2024-12-21 07:31:00,260] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 07:31:00,260] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# 293
# 65
# 315
# 315
# 179
# 185
# 315
# 315
# 315
# 315
# Instruction index:  10
# 315
# 315
# 315
# 315
# 315
# 315
# 72
# 126
# 124
# 315
# Instruction index:  20
# 315
# 315
# 315
# 315
# 315
# 67
# 315
# 144
# 91
# 315
# Instruction index:  30
# 315
# 159
# 314
# 315
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  40
# 315
# 68
# 315
# 314
# 120
# 102
# 315
# 315
# 147
# 127
# Instruction index:  50
# 315
# 315
# 160
# 275
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  60
# 69
# 315
# 315
# 314
# 60
# 79
# 315
# 157
# 67
# 214
# Instruction index:  70
# 315
# 315
# 315
# 186
# 315
# 315
# 315
# 316
# 80
# 153
# Instruction index:  80
# 193
# 158
# 315
# 315
# 315
# 210
# 315
# 89
# 315
# 315
# Instruction index:  90
# 315
# 315
# 315
# 315
# 134
# 315
# 315
# 78
# 315
# 83
# Run:  4
# [2024-12-21 07:45:24,654] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 07:45:24,655] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# 290
# 65
# 315
# 315
# 216
# 191
# 315
# 315
# 308
# 315
# Instruction index:  10
# 315
# 315
# 315
# 315
# 315
# 315
# 72
# 126
# 134
# 315
# Instruction index:  20
# 315
# 315
# 315
# 315
# 315
# 67
# 315
# 159
# 91
# 315
# Instruction index:  30
# 315
# 179
# 315
# 315
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  40
# 315
# 68
# 315
# 315
# 132
# 105
# 264
# 315
# 147
# 145
# Instruction index:  50
# 315
# 315
# 146
# 281
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  60
# 69
# 315
# 315
# 315
# 60
# 79
# 315
# 158
# 118
# 214
# Instruction index:  70
# 315
# 315
# 292
# 214
# 315
# 315
# 253
# 314
# 80
# 82
# Instruction index:  80
# 207
# 153
# 315
# 315
# 315
# 202
# 315
# 92
# 315
# 315
# Instruction index:  90
# 315
# 315
# 315
# 315
# 128
# 315
# 315
# 78
# 315
# 83
# Run:  5
# [2024-12-21 07:59:49,116] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 07:59:49,117] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# 309
# 65
# 315
# 315
# 180
# 176
# 315
# 315
# 308
# 315
# Instruction index:  10
# 315
# 315
# 315
# 315
# 315
# 315
# 71
# 126
# 131
# 315
# Instruction index:  20
# 315
# 315
# 315
# 315
# 315
# 67
# 315
# 136
# 91
# 315
# Instruction index:  30
# 315
# 158
# 315
# 315
# 315
# 262
# 315
# 315
# 315
# 314
# Instruction index:  40
# 315
# 67
# 315
# 315
# 141
# 109
# 315
# 315
# 207
# 114
# Instruction index:  50
# 315
# 315
# 147
# 275
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  60
# 69
# 315
# 315
# 315
# 60
# 79
# 315
# 103
# 115
# 212
# Instruction index:  70
# 315
# 315
# 298
# 145
# 315
# 315
# 315
# 315
# 80
# 82
# Instruction index:  80
# 211
# 153
# 315
# 315
# 315
# 204
# 315
# 89
# 315
# 202
# Instruction index:  90
# 315
# 315
# 315
# 315
# 136
# 315
# 315
# 78
# 315
# 83
# Run:  6
# [2024-12-21 08:14:06,104] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 08:14:06,104] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# 315
# 65
# 315
# 315
# 203
# 176
# 315
# 315
# 315
# 315
# Instruction index:  10
# 315
# 315
# 315
# 315
# 315
# 315
# 72
# 134
# 163
# 315
# Instruction index:  20
# 315
# 315
# 315
# 315
# 315
# 67
# 315
# 166
# 91
# 315
# Instruction index:  30
# 315
# 158
# 315
# 315
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  40
# 315
# 73
# 315
# 315
# 117
# 102
# 315
# 315
# 159
# 105
# Instruction index:  50
# 315
# 315
# 112
# 275
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  60
# 69
# 315
# 315
# 315
# 60
# 79
# 315
# 108
# 116
# 212
# Instruction index:  70
# 315
# 315
# 315
# 183
# 315
# 315
# 315
# 315
# 80
# 82
# Instruction index:  80
# 209
# 153
# 315
# 315
# 315
# 183
# 315
# 92
# 315
# 175
# Instruction index:  90
# 315
# 315
# 315
# 315
# 139
# 315
# 315
# 78
# 315
# 83
# Run:  7
# [2024-12-21 08:28:23,517] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 08:28:23,517] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# 315
# 65
# 315
# 315
# 203
# 178
# 315
# 315
# 306
# 315
# Instruction index:  10
# 315
# 315
# 315
# 287
# 311
# 315
# 72
# 126
# 163
# 315
# Instruction index:  20
# 315
# 315
# 292
# 315
# 299
# 67
# 315
# 136
# 91
# 315
# Instruction index:  30
# 315
# 193
# 315
# 315
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  40
# 315
# 73
# 315
# 314
# 143
# 102
# 315
# 315
# 169
# 148
# Instruction index:  50
# 315
# 315
# 146
# 282
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  60
# 69
# 315
# 315
# 315
# 60
# 79
# 313
# 103
# 108
# 212
# Instruction index:  70
# 315
# 315
# 315
# 198
# 176
# 315
# 315
# 315
# 80
# 82
# Instruction index:  80
# 197
# 153
# 315
# 315
# 315
# 202
# 315
# 143
# 315
# 156
# Instruction index:  90
# 315
# 315
# 314
# 315
# 138
# 315
# 315
# 78
# 315
# 83
# Run:  8
# [2024-12-21 08:42:39,908] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 08:42:39,908] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# 315
# 65
# 106
# 314
# 214
# 176
# 315
# 315
# 315
# 315
# Instruction index:  10
# 314
# 315
# 315
# 315
# 287
# 315
# 72
# 134
# 163
# 315
# Instruction index:  20
# 315
# 315
# 315
# 315
# 315
# 67
# 315
# 168
# 91
# 315
# Instruction index:  30
# 315
# 158
# 315
# 315
# 315
# 292
# 315
# 315
# 315
# 315
# Instruction index:  40
# 315
# 73
# 315
# 314
# 118
# 102
# 315
# 315
# 183
# 145
# Instruction index:  50
# 315
# 315
# 147
# 275
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  60
# 69
# 315
# 315
# 315
# 60
# 79
# 315
# 103
# 112
# 212
# Instruction index:  70
# 315
# 315
# 315
# 145
# 315
# 315
# 315
# 315
# 80
# 150
# Instruction index:  80
# 197
# 153
# 315
# 268
# 315
# 193
# 315
# 89
# 315
# 146
# Instruction index:  90
# 315
# 315
# 315
# 315
# 138
# 315
# 315
# 78
# 315
# 83
# Run:  9
# [2024-12-21 08:56:46,113] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 08:56:46,113] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# 315
# 65
# 315
# 315
# 216
# 170
# 315
# 315
# 309
# 315
# Instruction index:  10
# 315
# 315
# 315
# 315
# 284
# 315
# 72
# 126
# 145
# 315
# Instruction index:  20
# 315
# 315
# 315
# 315
# 315
# 67
# 315
# 168
# 91
# 315
# Instruction index:  30
# 315
# 119
# 315
# 315
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  40
# 315
# 73
# 315
# 315
# 132
# 109
# 315
# 315
# 121
# 164
# Instruction index:  50
# 315
# 315
# 147
# 275
# 315
# 315
# 315
# 315
# 315
# 315
# Instruction index:  60
# 69
# 315
# 315
# 315
# 60
# 79
# 315
# 112
# 113
# 212
# Instruction index:  70
# 315
# 315
# 299
# 216
# 315
# 315
# 171
# 315
# 80
# 157
# Instruction index:  80
# 191
# 153
# 315
# 290
# 315
# 202
# 315
# 89
# 315
# 161
# Instruction index:  90
# 315
# 315
# 315
# 315
# 139
# 315
# 315
# 78
# 315
# 83
# ========= End Model Evaluation ibm-granite/granite-3.1-1b-a400m-instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation HuggingFaceTB/SmolLM2-360M-Instruct ==========
# Run:  0
# [2024-12-21 09:11:01,044] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 09:11:01,044] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# 287
# 37
# 287
# 286
# 139
# 96
# 287
# 287
# 77
# 287
# Instruction index:  10
# 287
# 173
# 287
# 201
# 34
# 287
# 41
# 53
# 36
# 287
# Instruction index:  20
# 287
# 287
# 62
# 38
# 287
# 43
# 116
# 41
# 58
# 287
# Instruction index:  30
# 287
# 287
# 286
# 49
# 287
# 287
# 59
# 85
# 287
# 287
# Instruction index:  40
# 287
# 59
# 141
# 287
# 163
# 90
# 217
# 287
# 72
# 87
# Instruction index:  50
# 287
# 287
# 41
# 281
# 287
# 287
# 287
# 181
# 60
# 287
# Instruction index:  60
# 63
# 99
# 268
# 287
# 39
# 52
# 237
# 101
# 55
# 46
# Instruction index:  70
# 209
# 287
# 99
# 56
# 47
# 263
# 145
# 66
# 60
# 42
# Instruction index:  80
# 256
# 105
# 287
# 287
# 287
# 60
# 287
# 34
# 287
# 92
# Instruction index:  90
# 287
# 287
# 264
# 253
# 82
# 227
# 201
# 144
# 287
# 41
# Run:  1
# [2024-12-21 09:18:54,378] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21
# 291
# 243
# 291
# 291
# 291
# 291
# 291
# 291
# 291
# Instruction index:  60
# 114
# 291
# 291
# 42
# 115
# 104
# 291
# 227
# 136
# 214
# Instruction index:  70
# 291
# 291
# 291
# 98
# 91
# 291
# 289
# 291
# 160
# 215
# Instruction index:  80
# 242
# 111
# 291
# 291
# 291
# 69
# 291
# 290
# 291
# 271
# Instruction index:  90
# 291
# 291
# 291
# 290
# 291
# 291
# 180
# 86
# 291
# 164
# Run:  9
# [2024-12-21 11:45:06,876] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 11:45:06,876] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# 291
# 233
# 65
# 291
# 241
# 69
# 291
# 291
# 267
# 291
# Instruction index:  10
# 291
# 291
# 291
# 291
# 106
# 291
# 95
# 59
# 170
# 291
# Instruction index:  20
# 291
# 291
# 226
# 106
# 290
# 118
# 291
# 291
# 135
# 291
# Instruction index:  30
# 291
# 94
# 291
# 291
# 291
# 291
# 42
# 143
# 291
# 293
# Instruction index:  40
# 291
# 143
# 263
# 291
# 97
# 84
# 291
# 291
# 291
# 112
# Instruction index:  50
# 291
# 291
# 242
# 291
# 291
# 291
# 291
# 291
# 291
# 291
# Instruction index:  60
# 88
# 291
# 291
# 82
# 77
# 124
# 291
# 112
# 129
# 271
# Instruction index:  70
# 291
# 291
# 291
# 123
# 247
# 276
# 291
# 291
# 268
# 115
# Instruction index:  80
# 180
# 103
# 290
# 150
# 291
# 64
# 291
# 219
# 291
# 289
# Instruction index:  90
# 291
# 290
# 290
# 291
# 225
# 291
# 183
# 64
# 291
# 290
# ========= End Model Evaluation meta-llama/Llama-3.2-1B-Instruct ==========

# %% [markdown]
# ### 4-bit Quantization

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16
)
eval_models(model_id_list, nb_run=10, quantization_name="4-bit", quantization_config=quantization_config, instruction_list=df["instruction"], csv_suffixe="-q4bits")
# Out:
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation Qwen/Qwen2.5-0.5B-Instruct ==========
# Run:  0
# [2024-12-21 11:56:09,381] [zeus.device.gpu.nvidia](nvidia.py:47) pynvml is available and initialized.
# [2024-12-21 11:56:09,381] [zeus.device.cpu.rapl](rapl.py:136) RAPL is available.
# [2024-12-21 11:56:09,382] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:0/energy_uj
# [2024-12-21 11:56:09,384] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:0/intel-rapl:0:0/energy_uj
# [2024-12-21 11:56:09,385] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:0/intel-rapl:0:1/energy_uj
# [2024-12-21 11:56:09,386] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:1/energy_uj
# [2024-12-21 11:56:09,386] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 11:56:09,387] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# [2024-12-21 11:56:09,387] [zeus.utils.framework](framework.py:25) PyTorch with CUDA support is available.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-21 11:59:33,872] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 11:59:33,872] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-21 12:02:58,874] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 12:02:58,874] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-21 12:06:11,765] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 12:06:11,765] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-21 12:09:37,532] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 12:09:37,532] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-21 12:12:54,622] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 12:12:54,622] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-21 12:16:08,119] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 12:16:08,119] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-21 12:19:19,028] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 12:19:19,028] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-21 12:22:50,259] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 12:22:50,259] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-21 12:26:17,866] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 12:26:17,866] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation Qwen/Qwen2.5-0.5B-Instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation ibm-granite/granite-3.1-1b-a400m-instruct ==========
# Run:  0
# [2024-12-21 12:29:49,790] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 12:29:49,790] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-21 12:38:38,043] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 12:38:38,043] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-21 12:47:16,854] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 12:47:16,855] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-21 12:56:05,670] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 12:56:05,670] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-21 13:04:56,824] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 13:04:56,824] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-21 13:13:31,185] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 13:13:31,185] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-21 13:22:31,743] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 13:22:31,743] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-21 13:31:28,165] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 13:31:28,166] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-21 13:40:16,251] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 13:40:16,251] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-21 13:48:26,784] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 13:48:26,785] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation ibm-granite/granite-3.1-1b-a400m-instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation HuggingFaceTB/SmolLM2-360M-Instruct ==========
# Run:  0
# [2024-12-21 13:56:30,645] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 13:56:30,645] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-21 13:59:46,441] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 13:59:46,441] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-21 14:03:02,388] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:03:02,389] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-21 14:06:19,042] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:06:19,043] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-21 14:09:34,944] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:09:34,945] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-21 14:12:51,512] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:12:51,512] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-21 14:16:07,459] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:16:07,459] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-21 14:19:23,683] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:19:23,684] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-21 14:22:39,773] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:22:39,773] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-21 14:25:56,089] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:25:56,089] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation HuggingFaceTB/SmolLM2-360M-Instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation meta-llama/Llama-3.2-1B-Instruct ==========
# Run:  0
# [2024-12-21 14:29:16,791] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:29:16,792] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-21 14:33:51,152] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:33:51,152] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-21 14:38:34,462] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:38:34,462] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-21 14:43:20,104] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:43:20,104] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-21 14:48:06,939] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:48:06,940] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-21 14:52:49,906] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:52:49,906] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-21 14:57:36,202] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 14:57:36,202] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-21 15:02:17,892] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 15:02:17,892] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-21 15:07:07,429] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 15:07:07,429] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-21 15:11:52,229] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 15:11:52,229] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation meta-llama/Llama-3.2-1B-Instruct ==========

# %% [markdown]
# ### 4-bit Quantization + double quant

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True
)
eval_models(model_id_list, nb_run=10, quantization_name="4-bit + Nested Quantization", quantization_config=quantization_config,
            instruction_list=df["instruction"], csv_suffixe="-q4bits-double-quant")
# Out:
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation Qwen/Qwen2.5-0.5B-Instruct ==========
# Run:  0
# [2024-12-21 16:04:52,210] [zeus.device.gpu.nvidia](nvidia.py:47) pynvml is available and initialized.
# [2024-12-21 16:04:52,211] [zeus.device.cpu.rapl](rapl.py:136) RAPL is available.
# [2024-12-21 16:04:52,211] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:0/energy_uj
# [2024-12-21 16:04:52,214] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:0/intel-rapl:0:0/energy_uj
# [2024-12-21 16:04:52,215] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:0/intel-rapl:0:1/energy_uj
# [2024-12-21 16:04:52,217] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:1/energy_uj
# [2024-12-21 16:04:52,220] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 16:04:52,220] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# [2024-12-21 16:04:52,221] [zeus.utils.framework](framework.py:25) PyTorch with CUDA support is available.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-21 16:09:09,724] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 16:09:09,724] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-21 16:13:10,709] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 16:13:10,709] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-21 16:17:29,892] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 16:17:29,893] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-21 16:22:02,484] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 16:22:02,484] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-21 16:26:32,916] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 16:26:32,916] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-21 16:30:49,166] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 16:30:49,167] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-21 16:34:56,256] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 16:34:56,256] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-21 16:39:15,374] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 16:39:15,375] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-21 16:43:58,331] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 16:43:58,332] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation Qwen/Qwen2.5-0.5B-Instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation ibm-granite/granite-3.1-1b-a400m-instruct ==========
# Run:  0
# [2024-12-21 16:48:27,372] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 16:48:27,373] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-21 16:57:47,267] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 16:57:47,267] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-21 17:06:53,818] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 17:06:53,818] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-21 17:15:34,410] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 17:15:34,410] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-21 17:24:12,859] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 17:24:12,860] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-21 17:32:42,325] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 17:32:42,325] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-21 17:41:15,972] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 17:41:15,973] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-21 17:49:48,746] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 17:49:48,746] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-21 17:58:22,983] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 17:58:22,983] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-21 18:06:58,935] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 18:06:58,935] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation ibm-granite/granite-3.1-1b-a400m-instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation HuggingFaceTB/SmolLM2-360M-Instruct ==========
# Run:  0
# [2024-12-21 18:15:37,894] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 18:15:37,895] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-21 18:19:48,869] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 18:19:48,869] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-21 18:23:58,365] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 18:23:58,366] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-21 18:28:08,354] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 18:28:08,355] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-21 18:32:18,704] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 18:32:18,704] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-21 18:36:29,366] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 18:36:29,366] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-21 18:40:39,788] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 18:40:39,788] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-21 18:44:49,993] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 18:44:49,993] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-21 18:49:00,173] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 18:49:00,174] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-21 18:53:10,063] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 18:53:10,063] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation HuggingFaceTB/SmolLM2-360M-Instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation meta-llama/Llama-3.2-1B-Instruct ==========
# Run:  0
# [2024-12-21 18:57:21,772] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 18:57:21,773] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-21 19:02:33,492] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 19:02:33,492] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-21 19:07:47,664] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 19:07:47,665] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-21 19:13:09,908] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 19:13:09,909] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-21 19:18:24,190] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 19:18:24,190] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-21 19:23:31,171] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 19:23:31,172] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-21 19:28:51,527] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 19:28:51,528] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-21 19:34:04,488] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 19:34:04,488] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-21 19:39:14,517] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 19:39:14,517] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-21 19:44:23,771] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 19:44:23,771] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation meta-llama/Llama-3.2-1B-Instruct ==========

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
)
eval_models(model_id_list, nb_run=10, quantization_name="4-bit + Normal Float 4", quantization_config=quantization_config,
            instruction_list=df["instruction"], csv_suffixe="-q4bits-nf4")
# Out:
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation Qwen/Qwen2.5-0.5B-Instruct ==========
# Run:  0
# [2024-12-21 20:59:08,743] [zeus.device.gpu.nvidia](nvidia.py:47) pynvml is available and initialized.
# [2024-12-21 20:59:08,744] [zeus.device.cpu.rapl](rapl.py:136) RAPL is available.
# [2024-12-21 20:59:08,745] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:0/energy_uj
# [2024-12-21 20:59:08,747] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:0/intel-rapl:0:0/energy_uj
# [2024-12-21 20:59:08,748] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:0/intel-rapl:0:1/energy_uj
# [2024-12-21 20:59:08,749] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:1/energy_uj
# [2024-12-21 20:59:08,749] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 20:59:08,750] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# [2024-12-21 20:59:08,750] [zeus.utils.framework](framework.py:25) PyTorch with CUDA support is available.
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-21 21:02:27,293] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 21:02:27,293] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-21 21:06:08,040] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 21:06:08,041] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-21 21:09:40,093] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 21:09:40,094] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-21 21:13:06,698] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 21:13:06,699] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-21 21:16:59,699] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 21:16:59,699] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-21 21:20:32,189] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 21:20:32,190] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-21 21:24:01,008] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 21:24:01,009] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-21 21:27:36,962] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 21:27:36,963] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-21 21:31:01,398] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 21:31:01,398] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation Qwen/Qwen2.5-0.5B-Instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation ibm-granite/granite-3.1-1b-a400m-instruct ==========
# Run:  0
# [2024-12-21 21:34:31,029] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 21:34:31,029] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-21 21:42:48,692] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 21:42:48,693] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-21 21:51:04,648] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 21:51:04,648] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-21 21:59:17,533] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 21:59:17,533] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-21 22:07:30,500] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 22:07:30,500] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-21 22:15:42,798] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 22:15:42,798] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-21 22:23:50,936] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 22:23:50,936] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-21 22:32:01,009] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 22:32:01,009] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-21 22:40:06,884] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 22:40:06,884] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-21 22:48:17,945] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 22:48:17,945] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation ibm-granite/granite-3.1-1b-a400m-instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation HuggingFaceTB/SmolLM2-360M-Instruct ==========
# Run:  0
# [2024-12-21 22:56:31,046] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 22:56:31,046] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-21 23:00:17,564] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:00:17,564] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-21 23:04:05,460] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:04:05,461] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-21 23:07:55,120] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:07:55,121] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-21 23:11:43,660] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:11:43,661] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-21 23:15:32,022] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:15:32,022] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-21 23:19:20,375] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:19:20,375] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-21 23:23:08,920] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:23:08,921] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-21 23:26:57,170] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:26:57,170] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-21 23:30:46,028] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:30:46,028] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation HuggingFaceTB/SmolLM2-360M-Instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation meta-llama/Llama-3.2-1B-Instruct ==========
# Run:  0
# [2024-12-21 23:34:36,536] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:34:36,536] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-21 23:39:29,661] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:39:29,662] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-21 23:44:07,863] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:44:07,864] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-21 23:48:41,913] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:48:41,914] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-21 23:53:19,354] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:53:19,354] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-21 23:58:06,954] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-21 23:58:06,954] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-22 00:02:53,621] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 00:02:53,621] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-22 00:07:29,772] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 00:07:29,772] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-22 00:12:11,353] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 00:12:11,353] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-22 00:16:53,860] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 00:16:53,860] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation meta-llama/Llama-3.2-1B-Instruct ==========

# %% [markdown]
# ### 4-bit Quantization + NF4 + Nested Quantization

# %%
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_use_double_quant=True
)
eval_models(model_id_list, nb_run=10, quantization_name="4-bit + NF4 + Double Quant", quantization_config=quantization_config,
            instruction_list=df["instruction"], csv_suffixe="-q4bits-nf4-double-quant")
# Out:
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation Qwen/Qwen2.5-0.5B-Instruct ==========
# Run:  0
# [2024-12-22 08:09:48,625] [zeus.device.gpu.nvidia](nvidia.py:47) pynvml is available and initialized.
# [2024-12-22 08:09:48,625] [zeus.device.cpu.rapl](rapl.py:136) RAPL is available.
# [2024-12-22 08:09:48,626] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:0/energy_uj
# [2024-12-22 08:09:48,629] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:0/intel-rapl:0:0/energy_uj
# [2024-12-22 08:09:48,630] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:0/intel-rapl:0:1/energy_uj
# [2024-12-22 08:09:48,631] [RaplWraparoundTracker](rapl.py:82) Monitoring wrap around of /sys/class/powercap/intel-rapl/intel-rapl:1/energy_uj
# [2024-12-22 08:09:48,632] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 08:09:48,632] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# [2024-12-22 08:09:48,633] [zeus.utils.framework](framework.py:25) PyTorch with CUDA support is available.
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-22 08:14:13,527] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 08:14:13,527] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-22 08:18:27,601] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 08:18:27,602] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-22 08:22:45,930] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 08:22:45,931] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-22 08:26:59,566] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 08:26:59,567] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-22 08:31:30,982] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 08:31:30,982] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-22 08:35:47,163] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 08:35:47,163] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-22 08:40:10,744] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 08:40:10,744] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-22 08:44:30,324] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 08:44:30,325] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-22 08:48:49,141] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 08:48:49,141] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation Qwen/Qwen2.5-0.5B-Instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation ibm-granite/granite-3.1-1b-a400m-instruct ==========
# Run:  0
# [2024-12-22 08:53:04,273] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 08:53:04,273] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-22 09:02:07,444] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 09:02:07,444] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-22 09:11:20,013] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 09:11:20,013] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-22 09:20:30,352] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 09:20:30,353] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-22 09:29:38,229] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 09:29:38,229] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-22 09:38:42,495] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 09:38:42,495] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-22 09:47:56,722] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 09:47:56,722] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-22 09:57:05,303] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 09:57:05,304] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-22 10:06:14,162] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 10:06:14,163] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-22 10:15:18,929] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 10:15:18,930] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation ibm-granite/granite-3.1-1b-a400m-instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation HuggingFaceTB/SmolLM2-360M-Instruct ==========
# Run:  0
# [2024-12-22 10:24:26,500] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 10:24:26,501] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-22 10:29:19,016] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 10:29:19,017] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-22 10:34:11,490] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 10:34:11,491] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-22 10:39:03,889] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 10:39:03,889] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-22 10:43:56,389] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 10:43:56,390] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-22 10:48:49,325] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 10:48:49,325] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-22 10:53:42,847] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 10:53:42,848] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# /home/qperez/PycharmProjects/quantization-small-LLMs-energy-benchmark/.venv/lib/python3.12/site-packages/zeus/monitor/energy.py:402: UserWarning: The energy consumption of one or more GPUs was measured as zero. This means that the time duration of the measurement window was shorter than the GPU's energy counter update period. Consider turning on the `approx_instant_energy` option in `ZeusMonitor`, which approximates the energy consumption of a short time window as instant power draw x window duration.
#   warnings.warn(
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-22 10:58:36,310] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 10:58:36,310] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-22 11:03:29,806] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 11:03:29,806] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-22 11:08:23,420] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 11:08:23,420] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation HuggingFaceTB/SmolLM2-360M-Instruct ==========
# `low_cpu_mem_usage` was None, now default to True since model is quantized.
# Device set to use cuda:0
# ========= Begin Model Evaluation meta-llama/Llama-3.2-1B-Instruct ==========
# Run:  0
# [2024-12-22 11:13:22,655] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 11:13:22,655] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  1
# [2024-12-22 11:18:26,768] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 11:18:26,769] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  2
# [2024-12-22 11:23:42,584] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 11:23:42,584] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  3
# [2024-12-22 11:29:01,006] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 11:29:01,006] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  4
# [2024-12-22 11:34:20,430] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 11:34:20,430] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  5
# [2024-12-22 11:39:21,561] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 11:39:21,562] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  6
# [2024-12-22 11:44:31,249] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 11:44:31,249] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  7
# [2024-12-22 11:49:37,111] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 11:49:37,112] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  8
# [2024-12-22 11:54:38,453] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 11:54:38,454] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# Run:  9
# [2024-12-22 11:59:45,809] [zeus.monitor.energy](energy.py:208) Monitoring GPU indices [0].
# [2024-12-22 11:59:45,809] [zeus.monitor.energy](energy.py:209) Monitoring CPU indices [0, 1]
# Instruction index:  0
# Instruction index:  10
# Instruction index:  20
# Instruction index:  30
# Instruction index:  40
# Instruction index:  50
# Instruction index:  60
# Instruction index:  70
# Instruction index:  80
# Instruction index:  90
# ========= End Model Evaluation meta-llama/Llama-3.2-1B-Instruct ==========
